# %% [markdown]
# ## Import Data

# %%
# Import dependencies
import pandas as pd
from pathlib import Path

# %%
#Specify the path
raw_file = Path("./../Resources/WorldESGData2024.csv")

# %%
#Read the file
raw_data = pd.read_csv(raw_file)

# %%
#View the data
raw_data.head()
# Out:
#   Country Name Country Code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2  Afghanistan          AFG
# 3  Afghanistan          AFG
# 4  Afghanistan          AFG
#
#                                          Series Name        Series Code  \
# 0  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS
# 1            Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 2  Adjusted savings: natural resources depletion ...  NY.ADJ.DRES.GN.ZS
# 3  Adjusted savings: net forest depletion (% of GNI)  NY.ADJ.DFOR.GN.ZS
# 4                 Agricultural land (% of land area)     AG.LND.AGRI.ZS
#
#   2003 [YR2003] 2004 [YR2004] 2005 [YR2005] 2006 [YR2006] 2007 [YR2007]  \
# 0            10          11.1          12.5          13.9          15.3
# 1    18.9711647   23.81418228   28.66967201   33.54441833   38.44000244
# 2            ..            ..            ..            ..            ..
# ...

# %% [markdown]
# ## Get a sense of the data

# %%
# How many countries in the dataset?
raw_data["Country Name"].nunique()
#How many years in the dataset?
# Out:
# 207

# %%
raw_data.columns
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code',
#        '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]',
#        '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]', '2010 [YR2010]',
#        '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]',
#        '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]',
#        '2019 [YR2019]', '2020 [YR2020]', '2021 [YR2021]', '2022 [YR2022]',
#        '2023 [YR2023]'],
#       dtype='object')

# %% [markdown]
# ## Create the first two dataframes

# %%
#Create the coutry dataframe
country_columns_df = raw_data[['Country Name', 'Country Code']]

# %%
country_columns_df.head()
# Out:
#   Country Name Country Code
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2  Afghanistan          AFG
# 3  Afghanistan          AFG
# 4  Afghanistan          AFG

# %%
country_df = country_columns_df.drop_duplicates(inplace=False)

# %%
print(country_df)
# Out:
#                                             Country Name Country Code
# 0                                            Afghanistan          AFG
# 71                                               Albania          ALB
# 142                                              Algeria          DZA
# 213                                              Andorra          AND
# 284                                               Angola          AGO
# ...                                                  ...          ...
# 14413                                             Zambia          ZMB
# 14484                                           Zimbabwe          ZWE
# 14555                                                NaN          NaN
# 14558  Data from database: Environment Social and Gov...          NaN
# 14559                           Last Updated: 04/16/2024          NaN
#
# [208 rows x 2 columns]

# %%
country_df.shape
# Out:
# (208, 2)

# %%
country_df.tail(10)
# Out:
#                                             Country Name Country Code
# 14058                                         Uzbekistan          UZB
# 14129                                            Vanuatu          VUT
# 14200                                      Venezuela, RB          VEN
# 14271                                           Viet Nam          VNM
# 14342                                        Yemen, Rep.          YEM
# 14413                                             Zambia          ZMB
# 14484                                           Zimbabwe          ZWE
# 14555                                                NaN          NaN
# 14558  Data from database: Environment Social and Gov...          NaN
# 14559                           Last Updated: 04/16/2024          NaN

# %%
country_df.head()
# Out:
#     Country Name Country Code
# 0    Afghanistan          AFG
# 71       Albania          ALB
# 142      Algeria          DZA
# 213      Andorra          AND
# 284       Angola          AGO

# %%
#Create the Indicator datafrane
series_columns_df = raw_data[['Series Name', 'Series Code']]

# %%
series_columns_df.head()
# Out:
#                                          Series Name        Series Code
# 0  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS
# 1            Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 2  Adjusted savings: natural resources depletion ...  NY.ADJ.DRES.GN.ZS
# 3  Adjusted savings: net forest depletion (% of GNI)  NY.ADJ.DFOR.GN.ZS
# 4                 Agricultural land (% of land area)     AG.LND.AGRI.ZS

# %%
indicator_df = series_columns_df.drop_duplicates()

# %%
print(indicator_df)
# Out:
#                                              Series Name        Series Code
# 0      Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS
# 1                Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 2      Adjusted savings: natural resources depletion ...  NY.ADJ.DRES.GN.ZS
# 3      Adjusted savings: net forest depletion (% of GNI)  NY.ADJ.DFOR.GN.ZS
# 4                     Agricultural land (% of land area)     AG.LND.AGRI.ZS
# ...                                                  ...                ...
# 67                            Tree Cover Loss (hectares)     AG.LND.FRLS.HA
# 68     Unemployment, total (% of total labor force) (...     SL.UEM.TOTL.ZS
# 69     Unmet need for contraception (% of married wom...        SP.UWT.TFRT
# 70                    Voice and Accountability: Estimate             VA.EST
# 14555                                                NaN                NaN
#
# [72 rows x 2 columns]

# %%
indicator_df.tail()
# Out:
#                                              Series Name     Series Code
# 67                            Tree Cover Loss (hectares)  AG.LND.FRLS.HA
# 68     Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS
# 69     Unmet need for contraception (% of married wom...     SP.UWT.TFRT
# 70                    Voice and Accountability: Estimate          VA.EST
# 14555                                                NaN             NaN

# %%
year_data = Path("../Resources/Year.csv")

# %%
years = pd.read_csv(year_data)
print(years)
# Out:
#     Year
# 0   2003
# 1   2004
# 2   2005
# 3   2006
# 4   2007
# 5   2008
# 6   2009
# 7   2010
# 8   2011
# 9   2012
# 10  2013
# 11  2014
# 12  2015
# 13  2016
# 14  2017
# 15  2018
# 16  2019
# 17  2020
# 18  2021
# 19  2022
# 20  2023

# %%
matched_df = pd.DataFrame(columns = raw_data.columns)

# %%
for index, row_country in country_df.iterrows():
    country_names = row_country["Country Name"]
    for index, row_raw in raw_data.iterrows():
        if country_names == row_raw["Country Name"]:
            matched_df = matched_df.append(row_raw)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/tn/7xgwzpvd48l_vrzdsn4gsdxm0000gn/T/ipykernel_589/2751262165.py in ?()
#       1 for index, row_country in country_df.iterrows():
#       2     country_names = row_country["Country Name"]
#       3     for index, row_raw in raw_data.iterrows():
#       4         if country_names == row_raw["Country Name"]:
# ----> 5             matched_df = matched_df.append(row_raw)
#
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
for index, row_country in country_df.iterrows():
    country_names = row_country["Country Name"]
    matched_rows = raw_data[raw_data["Country Name"] == country_names]
    matched_df = pd.concat([matched_df, matched_rows])

# %%
matched_df
# Out:
#                                             Country Name Country Code  \
# 0                                            Afghanistan          AFG
# 1                                            Afghanistan          AFG
# 2                                            Afghanistan          AFG
# 3                                            Afghanistan          AFG
# 4                                            Afghanistan          AFG
# ...                                                  ...          ...
# 14552                                           Zimbabwe          ZWE
# 14553                                           Zimbabwe          ZWE
# 14554                                           Zimbabwe          ZWE
# 14558  Data from database: Environment Social and Gov...          NaN
# 14559                           Last Updated: 04/16/2024          NaN
#
#                                              Series Name        Series Code  \
# ...

# %%
for index, row_country in country_df.iterrows():
    country_names = row_country["Country Name"]
    matched_rows = raw_data[raw_data["Country Name"] == country_names]
    for index, 
    matched_df = pd.concat([matched_df, matched_rows])

# %%
for index, row in country_df.iterrows():
    country = row.iloc[0]
    matching_country = raw_data[raw_data.iloc[:,0] == country]
    if country == matching_country:
        pd.DataFrame(raw_data[raw_data.iloc[:,:]])

# %%
for index, row in country_df.iterrows():
    country = row.iloc[0]
    matching_country = indicator_df[indicator_df.iloc[:,0] == country] #filter out all the rows where the country mathes

# %%
for country_name in country_df["Country Name"]:
    for series_name in indicator_df["Series Name"]:
        if country_name == raw_data["Country Name"] & series_name == raw_data["Series Name"]:
            print(raw_data["2003 [YR2003]"])

# %%
for country_name in country_df["Country Name"]:
    for raw_country_name in raw_data["Country Name"]:
        for series_name in indicator_df["Series Name"]:
            for raw_series_name in raw_data["Series Name"]:
                if country_name == raw_country_name and series_name == raw_series_name:
                    print(raw_data["2003 [YR2003]"])

# %%
Country_list = []
Country_Code = []

for i in raw_data:
    for j in raw_data:
        Country_list.append(i[0])
        Country_Code.append(i[1])
        if

# %%
for country_name in country_df["Country Name"]: 
    for raw_country_name in raw_data["Country Name"]:
        if country_name == raw_country_name:
            print(country_name)
# Out:
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# ...

# %%
for row, index in country_df.iterrows():
